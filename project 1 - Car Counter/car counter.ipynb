# %% [markdown]
# # Install dependencies

# %%
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: cvzone in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 1)) (1.6.1)
# Requirement already satisfied: ultralytics in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 2)) (8.2.89)
# Requirement already satisfied: hydra-core in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: matplotlib in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 4)) (3.9.2)
# Requirement already satisfied: numpy in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 5)) (1.26.4)
# Requirement already satisfied: opencv-python in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 6)) (4.10.0.84)
# Requirement already satisfied: Pillow in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 7)) (10.4.0)
# Requirement already satisfied: PyYAML in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 8)) (6.0.2)
# Requirement already satisfied: requests in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: scipy in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: torch in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: torchvision in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 12)) (0.19.1)
# Requirement already satisfied: tqdm in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 13)) (4.66.5)
# Requirement already satisfied: filterpy in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 14)) (1.4.5)
# Requirement already satisfied: scikit-image in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 15)) (0.24.0)
# Requirement already satisfied: lapx in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from -r ../requirements.txt (line 16)) (0.5.10.post1)
# Requirement already satisfied: psutil in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from ultralytics->-r ../requirements.txt (line 2)) (6.0.0)
# Requirement already satisfied: py-cpuinfo in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from ultralytics->-r ../requirements.txt (line 2)) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from ultralytics->-r ../requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from ultralytics->-r ../requirements.txt (line 2)) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from ultralytics->-r ../requirements.txt (line 2)) (2.0.6)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from hydra-core->-r ../requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from hydra-core->-r ../requirements.txt (line 3)) (4.9.3)
# Requirement already satisfied: packaging in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from hydra-core->-r ../requirements.txt (line 3)) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from matplotlib->-r ../requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from requests->-r ../requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from requests->-r ../requirements.txt (line 9)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from requests->-r ../requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from requests->-r ../requirements.txt (line 9)) (2024.8.30)
# Requirement already satisfied: filelock in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (4.12.2)
# Requirement already satisfied: sympy in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (1.13.2)
# Requirement already satisfied: networkx in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (3.3)
# Requirement already satisfied: jinja2 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (3.1.4)
# Requirement already satisfied: fsspec in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (2024.9.0)
# Requirement already satisfied: setuptools in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from torch->-r ../requirements.txt (line 11)) (74.1.2)
# Requirement already satisfied: imageio>=2.33 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from scikit-image->-r ../requirements.txt (line 15)) (2.35.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from scikit-image->-r ../requirements.txt (line 15)) (2024.8.30)
# Requirement already satisfied: lazy-loader>=0.4 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from scikit-image->-r ../requirements.txt (line 15)) (0.4)
# Requirement already satisfied: pytz>=2020.1 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->-r ../requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from jinja2->torch->-r ../requirements.txt (line 11)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages (from sympy->torch->-r ../requirements.txt (line 11)) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Import dependencies

# %%
import math
from ultralytics import YOLO
import cv2
import cvzone
import torch
import numpy as np
from sort import *

print(torch.backends.mps.is_available())
# Out:
# True

# %% [markdown]
# # Initialization

# %%
model = YOLO("../yolo-weights/yolov10n.pt")

classNames = [
    "person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", 
    "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", 
    "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", 
    "giraffe", "backpack", "umbrella", "handbag", "tie", "suitcase", "frisbee", 
    "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove", 
    "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", 
    "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", 
    "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", 
    "pottedplant", "bed", "diningtable", "toilet", "tvmonitor", "laptop", "mouse", 
    "remote", "keyboard", "cell phone", "microwave", "oven", "toaster", "sink", 
    "refrigerator", "book", "clock", "vase", "scissors", "teddy bear", "hair drier", 
    "toothbrush"
]

cap = cv2.VideoCapture("../videos/cars.mp4")
cap.set(3, 640)
cap.set(4, 480)

tracker = Sort(max_age=30, min_hits=3, iou_threshold=0.4)

tracker_line = [(391,302),(722,313)]

car_ids = []

# %% [markdown]
# # Program Loop

# %%
while True:
    success, frame = cap.read()
    if not success:
        break

    # Create a mask with the same dimensions as the frame, initialized to zero (black)
    mask = np.zeros_like(frame)
    # Define the polygon coordinates
    polygon = np.array([[487, 194], [695, 191], [788, 529], [101, 427]], np.int32)
    # Draw the polygon on the mask with white color
    cv2.fillPoly(mask, [polygon], (255, 255, 255))

    # Apply the mask to the frame
    masked_frame = cv2.bitwise_and(frame, mask)

    results = model(masked_frame, stream=True, device="mps")
    
    detections = np.empty((0, 5))

    for r in results:
        boxes = r.boxes
        for box in boxes:
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
            w, h = x2-x1, y2-y1
            cls = int(box.cls[0])
            currentClass = classNames[cls]
            conf = math.ceil((box.conf[0]*100))/100

            if currentClass in ["car", "motorbike", "bus", "truck"] and conf > 0.3:
                cvzone.cornerRect(frame, (x1, y1, w, h), l=8, rt=1)
                # cvzone.putTextRect(frame, f'{conf}', (max(0, x1), max(35, y1)), scale=1, thickness=1, offset=16, colorR=(0, 255, 0))
                currentArray = np.array([x1, y1, x2, y2, conf])
                detections = np.vstack((detections, currentArray))
    
    results_tracker = tracker.update(detections)

    cv2.line(frame, (tracker_line[0][0], tracker_line[0][1]), (tracker_line[1][0], tracker_line[1][1]), (0, 0, 255), 2)

    def line_intersection(line1, line2):
        """Check if line1 intersects with line2"""
        x1, y1, x2, y2 = line1
        x3, y3, x4, y4 = line2

        # Calculate determinants
        den = (x1 - x2) * (y3 - y4) - (y1 - y2) * (x3 - x4)
        if den == 0:
            return False  # lines are parallel

        # Calculate the intersection point
        t = ((x1 - x3) * (y3 - y4) - (y1 - y3) * (x3 - x4)) / den
        u = -((x1 - x2) * (y1 - y3) - (y1 - y2) * (x1 - x3)) / den

        # Check if intersection is within the line segments
        return 0 <= t <= 1 and 0 <= u <= 1

    for result in results_tracker:
        x1, y1, x2, y2, track_id = result
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2-x1, y2-y1
        cv2.putText(frame, str(track_id), (x1, y1), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

        # Define the edges of the rectangle
        rect_edges = [
            (x1, y1, x1, y2),  # Left edge
            (x2, y2, x2, y1),  # Right edge
        ]

        # Check each edge for intersection with the tracker line
        for edge in rect_edges:
            if line_intersection(edge, (tracker_line[0][0], tracker_line[0][1], tracker_line[1][0], tracker_line[1][1])):
                cv2.putText(frame, f"Detected", (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
                if track_id not in car_ids:
                    car_ids.append(track_id)
    
    cv2.putText(frame, f"Cars Detected: {len(car_ids)}", (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    cv2.imshow("frame", frame)  # Show the original frame with detections
    cv2.waitKey(1)
# Out:
# /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages/torch/nn/functional.py:4050: UserWarning: MPS: passing scale factor to upsample ops is supported natively starting from macOS 13.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/UpSample.mm:248.)
#   return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
# /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages/ultralytics/nn/modules/head.py:149: UserWarning: torch.topk support for k>16 by MPS on MacOS 13+, please upgrade (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Shape.mm:71.)
#   index = scores.amax(dim=-1).topk(min(max_det, anchors))[1].unsqueeze(-1)
# 0: 384x640 3 cars, 335.8ms
# Speed: 22.6ms preprocess, 335.8ms inference, 29.1ms postprocess per image at shape (1, 3, 384, 640)
# /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages/ultralytics/utils/ops.py:221: UserWarning: MPS: nonzero op is supported natively starting from macOS 13.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Indexing.mm:335.)
#   output = [pred[pred[:, 4] > conf_thres][:max_det] for pred in prediction]
# /Users/nushankodikara/Projects/python-object-detection/venv/lib/python3.12/site-packages/torch/functional.py:911: UserWarning: MPS: _unique2 op is supported natively starting from macOS 13.0. Falling back on CPU. This may have performance implications. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/mps/operations/Unique.mm:317.)
#   output, inverse_indices, counts = torch._unique2(
# 0: 384x640 2 cars, 51.7ms
# Speed: 3.0ms preprocess, 51.7ms inference, 14.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.8ms
# Speed: 3.6ms preprocess, 55.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 61.7ms
# Speed: 4.3ms preprocess, 61.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 67.1ms
# Speed: 4.3ms preprocess, 67.1ms inference, 24.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 3.7ms preprocess, 48.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.5ms
# Speed: 3.0ms preprocess, 43.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.2ms
# Speed: 2.9ms preprocess, 47.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 50.1ms
# Speed: 3.2ms preprocess, 50.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.0ms
# Speed: 3.2ms preprocess, 49.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 49.2ms
# Speed: 3.0ms preprocess, 49.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.4ms
# Speed: 3.5ms preprocess, 48.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.1ms
# Speed: 3.3ms preprocess, 47.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.9ms
# Speed: 3.3ms preprocess, 47.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.8ms
# Speed: 3.2ms preprocess, 47.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 49.1ms
# Speed: 3.2ms preprocess, 49.1ms inference, 25.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 26.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 42.4ms
# Speed: 2.9ms preprocess, 42.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 47.5ms
# Speed: 3.3ms preprocess, 47.5ms inference, 26.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 46.4ms
# Speed: 2.8ms preprocess, 46.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 47.4ms
# Speed: 3.3ms preprocess, 47.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 47.0ms
# Speed: 2.7ms preprocess, 47.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 45.9ms
# Speed: 2.9ms preprocess, 45.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 47.3ms
# Speed: 3.2ms preprocess, 47.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 49.9ms
# Speed: 3.3ms preprocess, 49.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.1ms
# Speed: 3.4ms preprocess, 47.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 48.0ms
# Speed: 3.2ms preprocess, 48.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 48.0ms
# Speed: 3.1ms preprocess, 48.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.3ms
# Speed: 3.6ms preprocess, 47.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.0ms
# Speed: 3.2ms preprocess, 46.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 44.8ms
# Speed: 3.2ms preprocess, 44.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.9ms
# Speed: 3.1ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46
2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.3ms
# Speed: 3.3ms preprocess, 47.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 45.8ms
# Speed: 2.8ms preprocess, 45.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.2ms
# Speed: 2.9ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.2ms
# Speed: 3.2ms preprocess, 51.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.6ms
# Speed: 3.2ms preprocess, 47.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.1ms
# Speed: 2.8ms preprocess, 47.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.4ms
# Speed: 3.2ms preprocess, 47.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 48.0ms
# Speed: 3.3ms preprocess, 48.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 48.7ms
# Speed: 3.3ms preprocess, 48.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 45.5ms
# Speed: 2.8ms preprocess, 45.5ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 47.9ms
# Speed: 3.5ms preprocess, 47.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 47.8ms
# Speed: 3.2ms preprocess, 47.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.2ms
# Speed: 3.3ms preprocess, 47.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 43.1ms
# Speed: 3.0ms preprocess, 43.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 47.6ms
# Speed: 2.8ms preprocess, 47.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.4ms
# Speed: 3.1ms preprocess, 48.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 47.9ms
# Speed: 3.3ms preprocess, 47.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.1ms
# Speed: 3.3ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 44.8ms
# Speed: 3.1ms preprocess, 44.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 45.9ms
# Speed: 3.2ms preprocess, 45.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.5ms
# Speed: 3.3ms preprocess, 48.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.2ms
# Speed: 3.2ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.7ms
# Speed: 3.4ms preprocess, 46.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 47.5ms
# Speed: 3.3ms preprocess, 47.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.0ms
# Speed: 3.1ms preprocess, 48.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.8ms
# Speed: 3.5ms preprocess, 48.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 49.1ms
# Speed: 3.9ms preprocess, 49.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 49.1ms
# Speed: 3.4ms preprocess, 49.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 60.4ms
# Speed: 3.3ms preprocess, 60.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 55.0ms
# Speed: 3.9ms preprocess, 55.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.9ms
# Speed: 3.4ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.5ms
# Speed: 3.6ms preprocess, 50.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 47.4ms
# Speed: 3.5ms preprocess, 47.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 truck, 47.5ms
# Speed: 3.2ms preprocess, 47.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 47.7ms
# Speed: 3.2ms preprocess, 47.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.1ms
# Speed: 3.3ms preprocess, 48.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 48.3ms
# Speed: 3.5ms preprocess, 48.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 79.9ms
# Speed: 3.5ms preprocess, 79.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 55.1ms
# Speed: 3.4ms preprocess, 55.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 51.1ms
# Speed: 3.2ms preprocess, 51.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.4ms
# Speed: 3.3ms preprocess, 48.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.3ms
# Speed: 3.2ms preprocess, 46.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 46.6ms
# Speed: 3.2ms preprocess, 46.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.2ms
# Speed: 3.3ms preprocess, 47.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 45.1ms
# Speed: 3.0ms preprocess, 45.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.9ms
# Speed: 3.2ms preprocess, 48.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.6ms
# Speed: 3.4ms preprocess, 46.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.3ms
# Speed: 3.1ms preprocess, 46.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 112.9ms
# Speed: 3.2ms preprocess, 112.9ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 41.7ms
# Speed: 2.9ms preprocess, 41.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 37.7ms
# Speed: 2.4ms preprocess, 37.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 42.2ms
# Speed: 2.9ms preprocess, 42.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 58.4ms
# Speed: 3.0ms preprocess, 58.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 55.4ms
# Speed: 3.4ms preprocess, 55.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 55.1ms
# Speed: 3.3ms preprocess, 55.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 52.0ms
# Speed: 3.2ms preprocess, 52.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 49.9ms
# Speed: 5.0ms preprocess, 49.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 48.1ms
# Speed: 3.8ms preprocess, 48.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars,
3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.5ms
# Speed: 3.2ms preprocess, 47.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.4ms
# Speed: 2.8ms preprocess, 48.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.3ms
# Speed: 2.8ms preprocess, 48.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.2ms
# Speed: 3.3ms preprocess, 48.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 48.1ms
# Speed: 3.5ms preprocess, 48.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.6ms
# Speed: 2.8ms preprocess, 47.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.0ms
# Speed: 3.6ms preprocess, 48.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 47.3ms
# Speed: 3.3ms preprocess, 47.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 47.6ms
# Speed: 3.3ms preprocess, 47.6ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 46.8ms
# Speed: 3.1ms preprocess, 46.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 46.8ms
# Speed: 3.1ms preprocess, 46.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 47.0ms
# Speed: 3.3ms preprocess, 47.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 46.9ms
# Speed: 3.4ms preprocess, 46.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 46.9ms
# Speed: 3.2ms preprocess, 46.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 52.1ms
# Speed: 2.8ms preprocess, 52.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 51.9ms
# Speed: 3.3ms preprocess, 51.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 55.8ms
# Speed: 3.8ms preprocess, 55.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 46.6ms
# Speed: 3.2ms preprocess, 46.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.6ms
# Speed: 3.4ms preprocess, 47.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.3ms
# Speed: 3.3ms preprocess, 47.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 48.0ms
# Speed: 3.3ms preprocess, 48.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.8ms
# Speed: 3.3ms preprocess, 46.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.7ms
# Speed: 3.5ms preprocess, 47.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.9ms
# Speed: 3.3ms preprocess, 47.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.8ms
# Speed: 3.2ms preprocess, 44.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 44.8ms
# Speed: 2.6ms preprocess, 44.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.4ms
# Speed: 3.2ms preprocess, 48.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 46.2ms
# Speed: 3.3ms preprocess, 46.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 47.4ms
# Speed: 3.2ms preprocess, 47.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 48.3ms
# Speed: 3.2ms preprocess, 48.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 44.6ms
# Speed: 3.2ms preprocess, 44.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 51.7ms
# Speed: 3.5ms preprocess, 51.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 46.2ms
# Speed: 3.2ms preprocess, 46.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 48.8ms
# Speed: 3.2ms preprocess, 48.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 48.2ms
# Speed: 3.2ms preprocess, 48.2ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 46.5ms
# Speed: 3.2ms preprocess, 46.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 47.4ms
# Speed: 3.2ms preprocess, 47.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 47.4ms
# Speed: 3.2ms preprocess, 47.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 46.7ms
# Speed: 3.1ms preprocess, 46.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.3ms
# Speed: 3.2ms preprocess, 48.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 46.3ms
# Speed: 3.4ms preprocess, 46.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 cars, 46.9ms
# Speed: 3.3ms preprocess, 46.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.0ms
# Speed: 2.8ms preprocess, 47.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 44.2ms
# Speed: 2.6ms preprocess, 44.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 47.1ms
# Speed: 3.3ms preprocess, 47.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.8ms
# Speed: 3.1ms preprocess, 46.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 46.6ms
# Speed: 3.4ms preprocess, 46.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.3ms
# Speed: 3.0ms preprocess, 47.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 47.2ms
# Speed: 3.2ms preprocess, 47.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 48.2ms
# Speed: 3.1ms preprocess, 48.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Coordinate Checker

# %%
success, frame = cap.read()  # Read the first frame
if success:
    cv2.imshow("First Frame", frame)

    def get_coordinates(event, x, y, flags, param):
        if event == cv2.EVENT_LBUTTONDOWN:
            print(f"Coordinates: ({x}, {y})")

    cv2.setMouseCallback("First Frame", get_coordinates)

    while True:
        if cv2.waitKey(1) & 0xFF == ord('q'):  # Press 'q' to exit
            break

cv2.destroyAllWindows()
cap.release()
